# %%
#Helloworld program
print('Helllo World!')
print('What is your name?')
name=input()
print('It is good to meet  you '+name)
# Out:
# Helllo World!
# What is your name?
# Junhyung
# It is good to meet  you Junhyung

# %% [markdown]
# '''키보드에 입력한 값을 변수 a 에 대입
# : a=input()'''
