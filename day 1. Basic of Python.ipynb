# %%
a = 5

# %%
print(a)
# Out:
# 5

# %%
a = 3
b = 5

# %%
a + b
# Out:
# 8

# %%
a - b
# Out:
# -2

# %%
a * b
# Out:
# 15

# %%
a / b
# Out:
# 0.6

# %%
a ** b
# Out:
# 243

# %%
3 + 5
# Out:
# 8

# %%
7 % 3
# Out:
# 1

# %%
7 // 3
# Out:
# 2

# %%
a = [1, 2, 3, 4, 5]
print(a)
# Out:
# [1, 2, 3, 4, 5]

# %%
a[0]
# Out:
# 1

# %%
a[3]
# Out:
# 4

# %%
a[-1]
# Out:
# 5

# %%
a[1:3] # 1부터 3전까지 // 1부터 2까지
# Out:
# [2, 3]

# %%
a[:3]
# Out:
# [1, 2, 3]

# %%
a[1:]
# Out:
# [2, 3, 4, 5]

# %%
a = [1,2,3]

a.append(4)

a
# Out:
# [1, 2, 3, 4]

# %%
a = [1,4,3,2]

a.sort()

a
# Out:
# [1, 2, 3, 4]

# %%
a.append([4,5])
a
# Out:
# [1, 2, 3, 4, [4, 5]]

# %%
a = [1,2,3]
b = [4,5,6]

a + b
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
a - b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-09bd029d0285> in <module>()
# ----> 1 a - b
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'
