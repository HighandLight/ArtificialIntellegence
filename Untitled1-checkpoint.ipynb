# %%
print("hello world")
# Out:
# hello world

# %%
print('안녕하세요
# Out:
#   File "<ipython-input-2-d148e982516e>", line 1
#     print('안녕하세요
#                 ^
# SyntaxError: EOL while scanning string literal

# %%
#이러면 에러난다.

# %%
a=10
a
# Out:
# 10

# %%
b=20
b
# Out:
# 20

# %%
a+b
# Out:
# 30

# %%
a=40

# %%
a+b
# Out:
# 60

# %%
a+a
# Out:
# 80
